# %%
#Recursion

# %%
# 1 
"""Вам доступна функция traffic(), реализованная с помощью цикла while, которая принимает в качестве аргумента число 
n и выводит n раз строку Не парковаться. Перепишите данную функцию с использованием рекурсии, чтобы она выполняла ту же задачу.
Input 1:
traffic(3)
Output 1:
Не парковаться
Не парковаться
Не парковаться

Input 2:
traffic(5)
Output 2:
Не парковаться
Не парковаться
Не парковаться
Не парковаться
Не парковаться

Input 3:
traffic(0)
Output 3:
"""

# %%
# Перепишите код
def traffic(n):
    if n == 0: return
    print('Не парковаться')
    traffic(n - 1)

traffic(3)
# Out:
# Не парковаться
# Не парковаться
# Не парковаться

# %%
#2
"""Вам доступен список numbers, содержащий ровно 100 целых чисел. 
Дополните приведенный ниже код с использованием рекурсии, чтобы он вывел все элементы этого списка от первого до последнего, 
каждый на отдельный строке, в следующем формате:
Элемент <индекс элемента>: <значение элемента>
Элемент 0: 243
Элемент 1: -279
Элемент 2: 395
...  """

# %%
numbers = [243, -279, 395, 130, 89, 269, 861, 669, 939, 367, -46, 710, 841, -280, -244, 274, -132, 273, 418, 432, -341, 437, 360, 960, 195, 792, 106, 461, -35, 980, -80, 540, -358, 69, -26, -416, 597, 96, 533, 232, 755, 894, 331, 323, -383, -386, 231, 436, 553, 967, 166, -151, 772, 434, 325, 301, 275, 431, 556, 728, 558, 702, 463, 127, 984, 212, 876, -287, -16, -177, 577, 604, 116, 500, 653, 669, 916, 802, 817, 762, -210, -353, 144, -351, 777, 805, 692, 22, -303, 249, 190, 411, 236, -274, 174, 380, 71, 124, -85, 430]
# Напишите Ваш код здесь

def print_nums(n = 0):
    if n == len(numbers): return
    print(f'{n}: {numbers[n]}')
    print_nums(n + 1)

print_nums()
# Out:
# 0: 243
# 1: -279
# 2: 395
# 3: 130
# 4: 89
# 5: 269
# 6: 861
# 7: 669
# 8: 939
# 9: 367
# 10: -46
# 11: 710
# 12: 841
# 13: -280
# 14: -244
# 15: 274
# 16: -132
# 17: 273
# 18: 418
# 19: 432
# 20: -341
# 21: 437
# 22: 360
# 23: 960
# 24: 195
# 25: 792
# 26: 106
# 27: 461
# 28: -35
# 29: 980
# 30: -80
# 31: 540
# 32: -358
# 33: 69
# 34: -26
# 35: -416
# 36: 597
# 37: 96
# 38: 533
# 39: 232
# 40: 755
# 41: 894
# 42: 331
# 43: 323
# 44: -383
# 45: -386
# 46: 231
# 47: 436
# 48: 553
# 49: 967
# 50: 166
# 51: -151
# 52: 772
# 53: 434
# 54: 325
# 55: 301
# 56: 275
# 57: 431
# 58: 556
# 59: 728
# 60: 558
# 61: 702
# 62: 463
# 63: 127
# 64: 984
# 65: 212
# 66: 876
# 67: -287
# 68: -16
# 69: -177
# 70: 577
# 71: 604
# 72: 116
# 73: 500
# 74: 653
# 75: 669
# 76: 916
# 77: 802
# 78: 817
# 79: 762
# 80: -210
# 81: -353
# 82: 144
# 83: -351
# 84: 777
# 85: 805
# 86: 692
# 87: 22
# 88: -303
# 89: 249
# 90: 190
# 91: 411
# 92: 236
# 93: -274
# 94: 174
# 95: 380
# 96: 71
# 97: 124
# 98: -85
# 99: 430

# %%
#3
"""Реализуйте функцию triangle() с использованием рекурсии, которая принимает один аргумент:
h — натуральное число
Input 1:
triangle(3)
Output 1:
***
**
*

Input 2:
triangle(5)
Output 2:
*****
****
***
**
*

 """

# %%
def triangle(n):
    if n == 0: return
    print('*' * n)
    triangle(n - 1)

triangle(3)
# Out:
# ***
# **
# *

# %%
#4
"""Напишите программу с использованием рекурсивной функции, которая выводит изображение песочных часов, составленное из цифр 
1,2,3, и 4:

1111111111111111    # 16 раз
  222222222222      # 12 раз
    33333333        # 8 раз
      4444          # 4 раза
    33333333        # 8 раз
  222222222222      # 12 раз
1111111111111111    # 16 раз
                  
Формат входных данных
На вход программе ничего не подается. """

# %%
def func(n = 1, rev = False):
    if n < 1: return
    print(2 * (n - 1) * ' ', end='')

    print(f'{n}' * 2 * (8 - 2 * (n - 1)))

    if n == 4: 
        func(n - 1, True)
        return

    if rev: func(n - 1, rev)
    else: func(n + 1, rev)

func()
# Out:
# 1111111111111111
#   222222222222
#     33333333
#       4444
#     33333333
#   222222222222
# 1111111111111111

# %%
#5
"""Реализуйте функцию print_digits() с использованием рекурсии, которая принимает один аргумент:
number — натуральное число
Функция должна выводить все цифры числа number, начиная со старших разрядов, каждое на отдельной строке.
Input 1:
print_digits(12345)
Output 1:
1
2
3
4
5

Input 2:
print_digits(2077)
Output 2:
2
0
7
7

Input 3:
print_digits(8)
Output 3:
8                  """

# %%
def print_digits(n):
    if isinstance(n, int): 
        print_digits(str(n))
        return
    
    if not n: return

    print(n[0])
    print_digits(n[1:])

print_digits(12345)
print()
print_digits(2077)
print()
print_digits(8)
# Out:
# 1
# 2
# 3
# 4
# 5
#
# 2
# 0
# 7
# 7
#
# 8

# %%
#6
"""Напишите программу с использованием рекурсии, которая принимает на вход число и выводит количество цифр в этом числе.
Формат входных данных
На вход программе подается неотрицательное целое число.
Формат выходных данных
Программа должна определить количество цифр в введенном числе и вывести полученный результат.
Input 1:
50
Output 1:
2

Input 2:
17488
Output 2:
5

Input 3:
7
Output 3:
1    """

# %%
def digits_count(n):
    if n == 0: return 0
    count = 1
    count += digits_count(n // 10)

    return count

print(digits_count(12435))
# Out:
# 5

# %%
#7
"""Реализуйте функцию get_pow() с использованием рекурсии, которая принимает два аргумента в следующем порядке:
a — положительное целое число
n — неотрицательное целое число
Функция должна вычислять значение a в степени n и возвращать полученный результат.
При решении не используйте оператор возведения в степень **.
Input 1:
print(get_pow(5, 2))
Output 1:
25

Input 2:
print(get_pow(99, 0))
Output 2:
1

Input 3:
print(get_pow(2, 10))
Output 3:
1024       """

# %%
def get_pow(a, n):
    if not n: return 1

    if n % 2 == 0:
        return get_pow(a*a, n // 2)
    else:
        return a * get_pow(a, n - 1)
    
print(get_pow(5, 2))
print(get_pow(99, 0))
print(get_pow(2, 10))
# Out:
# 25
# 1
# 1024

# %%
#8
"""Реализуйте функцию recursive_sum() с использованием рекурсии, которая принимает два аргумента в следующем порядке:
a — неотрицательное целое число
b — неотрицательное целое число
Функция должна возвращать сумму чисел a и b. При вычислении суммы функция:
не должна использовать циклы
из всех арифметических операций должна использовать только +1 и −1

Input 1:
print(recursive_sum(10, 22))
Output 1:
32

Input 2:
print(recursive_sum(99, 0))
Output 2:
99

Input 3:
print(recursive_sum(0, 0))
Output 3:
0                               """

# %%
def recursive_sum(a, b):
    if b == 0: return a

    return recursive_sum(a + 1, b - 1)

print(recursive_sum(10, 22))
# Out:
# 32

# %%
#9
"""Реализуйте функцию to_binary() с использованием рекурсии, которая принимает один аргумент:
number — неотрицательное целое число
Функция должна возвращать строковое представление числа number в двоичной системе счисления.
Input 1:
print(to_binary(15))
Output 1:
1111

Input 2:
print(to_binary(0))
Output 2:
0

Input 3:
print(to_binary(1))
Output 3:
1                """

# %%
def to_binary(n):
    res = str(n % 2)
    n //= 2
    if (n != 0) :
        res = to_binary(n) + res

    return res 

print(to_binary(15))
print(to_binary(0))
print(to_binary(1))
# Out:
# 1111
# 0
# 1

# %%
#10
"""В первый год в пруду живет 77 лягушек. Каждый год из пруда вылавливают 30 лягушек, а оставшиеся размножаются,
и их становится в три раза больше. Так, количество лягушек k-й год  может быть описано формулой:
Fk = 3*(F(k-1) - 30)
Реализуйте функцию number_of_frogs() с использованием рекурсии, которая принимает один аргумент:
year — натуральное число
Функция должна возвращать единственное число — количество лягушек в пруду в году year.
Input 1:
print(number_of_frogs(2))
Output 1:
141

Input 2:
print(number_of_frogs(10))
Output 2:
629901

Input 3:
print(number_of_frogs(1))
Output 3:
77        """

# %%
def number_of_frogs(y):
    if y == 1: return 77
    return 3 * (number_of_frogs(y - 1) - 30)

print(number_of_frogs(2))
print(number_of_frogs(10))
print(number_of_frogs(1))
# Out:
# 141
# 629901
# 77
